# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

df = pd.read_csv('res.csv')

X = df[['Отставание, %']].values.reshape(-1, 1)
y = df['Текучесть, %'].values.reshape(-1, 1)

model = LinearRegression()
model.fit(X, y)

plt.scatter(X, y, color='deeppink')
plt.plot(X, model.predict(X), color='purple')
plt.xlabel('Отставание, %')
plt.ylabel('Текучесть, %')
plt.show()

# %%
import sklearn.metrics as metrics

y_predicted = coeffs[0] * df['Текучесть, %'] + coeffs[1]

r2_score = metrics.r2_score(df['Отставание, %'], y_predicted)
print('Коэффициент детерминации: ', r2_score)

mse = metrics.mean_squared_error(df['Отставание, %'], y_predicted)
print('Среднеквадратичное отклонение: ', mse)

mae = metrics.mean_absolute_error(df['Отставание, %'], y_predicted)
print('Среднее абсолютное отклонение: ', mae)



print('Коэффициент при x (коэффициент наклона): ', coeffs[0])
print('Свободный член (пересечение с осью y): ', coeffs[1])
# Out:
# Коэффициент детерминации:  -15.98252022331955
# Среднеквадратичное отклонение:  755.2318654580173
# Среднее абсолютное отклонение:  26.254262169347903
# Коэффициент при x (коэффициент наклона):  -0.34233976597719457
# Свободный член (пересечение с осью y):  13.598343891387547
